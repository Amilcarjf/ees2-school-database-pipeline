# %% [markdown]
# # Test manual — utils_texto.py
#
# Notebook de laboratorio para probar funciones genéricas de limpieza textual.
#
# Este notebook no forma parte del pipeline operativo.
# Se usa únicamente para verificar comportamiento de funciones antes de integrarlas en otros módulos.

# %%
import sys

sys.path.append(r"C:\ees2-school-database-pipeline")

# %%
from src.utils_texto import limpiar_texto

# %%
limpiar_texto("   PEREZ     Jose   ")
# Out:
# 'PEREZ Jose'

# %%
from src.utils_texto import limpiar_texto

# %%
limpiar_texto("   PEREZ     Jose   ")
# Out:
# 'PEREZ Jose'

# %%
from src.utils_texto import convertir_a_texto, colapsar_espacios, normalizar_unicode

# %%
convertir_a_texto(123)
# Out:
# '123'

# %%
colapsar_espacios("   PEREZ     Jose   ")
# Out:
# 'PEREZ Jose'

# %%
normalizar_unicode("José")
# Out:
# 'José'
