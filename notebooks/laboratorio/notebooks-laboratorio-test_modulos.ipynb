# %% [markdown]
# # Test manual — extractores.py y normalizacion.py
#
# Notebook de laboratorio para probar funciones de extracción y normalización desde las fuentes declaradas.
#
# Este notebook no forma parte del pipeline operativo.
# Se usa únicamente para verificar comportamiento de funciones antes de integrarlas en otros módulos.

# %% [markdown]
# # Prueba de extractores.py para fuente Datos

# %%
import sys

sys.path.append(r"C:\ees2-school-database-pipeline")

# %%
from src.extractores import extraer_datos_raw

# %%
ruta = r"C:\ees2-school-database-pipeline\data\raw\datos\1°1° 2025 Datos.docx"

df_datos_raw = extraer_datos_raw(
    ruta_archivo=ruta,
    curso="1",
    division="1",
    anio="2025"
)

df_datos_raw.head()
# Out:
#   Nº   APELLIDO Y NOMBRES DEL ALUMNO  LM    F    Leg ESC    D.N.I.      F.N.  \
# 0                   ACHIGAR, Tiziano  42  240  31/25  25  52746170  26/12/12
# 1               AGUILAR, Ian Nicolás  42  241  32/25   4  52778569  27/11/12
# 2          ALTAMIRANO, Joaquin Román  42  242  33/25   8  52887715  14/01/13
# 3                ARANDA, Maia Mariel  42  243  34/25   1  52617713  06/07/12
# 4     CARRERAS FLAMMINI, Paula Sofía  42  244  35/25   8  52961006  01/02/13
#
#         Lugar   E               Dirección      Teléfono curso division  anio  \
# 0  Punta Alta  12           Humberto 2538  2932-520752M     1        1  2025
# 1  Punta Alta  12  Bº Albatros XXVII c393  2932-573441M     1        1  2025
# 2    San Juan  12           Humberto 1916  2932-614538M     1        1  2025
# 3  Punta Alta  12         Entre Ríos 1899  2932-520048P     1        1  2025
# 4   Juris Fed  12           Humberto 2447  2932-505154M     1        1  2025
#
# ...

# %%
df_datos_raw.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Nº                             27 non-null     str
#  1   APELLIDO Y NOMBRES DEL ALUMNO  27 non-null     str
#  2   LM                             27 non-null     str
#  3   F                              27 non-null     str
#  4   Leg                            27 non-null     str
#  5   ESC                            27 non-null     str
#  6   D.N.I.                         27 non-null     str
#  7   F.N.                           27 non-null     str
#  8   Lugar                          27 non-null     str
#  9   E                              27 non-null     str
#  10  Dirección                      27 non-null     str
#  11  Teléfono                       27 non-null     str
#  12  curso                          27 non-null     str
# ...

# %%
df_datos_raw.tail()
# Out:
#    Nº    APELLIDO Y NOMBRES DEL ALUMNO  LM   F    Leg ESC    D.N.I.      F.N.  \
# 22     SANCHEZ PEÑA, Milagros Agostina  43  13  54/25   1  50467337  22/04/11
# 23                UBEDA, Franco Lionel  43  14  55/25  25  48345434  11/07/10
# 24               UÑATE, Thiago Santino  43  15  56/25  25  52961001  04/02/13
# 25           ZACARIAS, Kevin Alejandro  43  16  57/25   4  52617707  26/07/12
# 26              ZERPA, Fernando Damián  43  17  58/25  16  52710252  13/09/12
#
#          Lugar   E               Dirección      Teléfono curso division  anio  \
# 22   Juris Fed  14  Bº Albatros XXVII c160  2932-573334M     1        1  2025
# 23   Juris Fed  14           Humberto 3655  2932-509256M     1        1  2025
# 24   Juris Fed  12           Buchardo 3266  2932-631139M     1        1  2025
# 25  Punta Alta  12      17 de febrero 1794  2932-457126M     1        1  2025
# 26       Bs As  12        Río Colorado 210  2932-476473P     1        1  2025
#
# ...

# %%
df_datos_raw.columns
# Out:
# Index(['Nº', 'APELLIDO Y NOMBRES DEL ALUMNO', 'LM', 'F', 'Leg', 'ESC',
#        'D.N.I.', 'F.N.', 'Lugar', 'E', 'Dirección', 'Teléfono', 'curso',
#        'division', 'anio', 'fuente', 'archivo_origen'],
#       dtype='str')

# %%
df_datos_raw.shape
# Out:
# (27, 17)

# %% [markdown]
# # Prueba de extractores.py para fuente Legajos

# %%
from src.extractores import extraer_legajos_raw

# %%
ruta_legajos = r"C:\ees2-school-database-pipeline\data\raw\legajos\1°1° 2025 Legajos.docx"

df_legajos_raw = extraer_legajos_raw(
    ruta_archivo=ruta_legajos,
    curso="1",
    division="1",
    anio="2025"
)

# %%
df_legajos_raw.shape
# Out:
# (27, 10)

# %%
df_legajos_raw.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Nº                             27 non-null     str
#  1   APELLIDO Y NOMBRES DEL ALUMNO  27 non-null     str
#  2   LM                             27 non-null     str
#  3   F                              27 non-null     str
#  4   Leg                            27 non-null     str
#  5   curso                          27 non-null     str
#  6   division                       27 non-null     str
#  7   anio                           27 non-null     str
#  8   fuente                         27 non-null     str
#  9   archivo_origen                 27 non-null     str
# dtypes: str(10)
# memory usage: 2.2 KB

# %%
df_legajos_raw.head()
# Out:
#   Nº   APELLIDO Y NOMBRES DEL ALUMNO  LM    F    Leg curso division  anio  \
# 0                   ACHIGAR, Tiziano  42  240  31/25     1        1  2025
# 1               AGUILAR, Ian Nicolás  42  241  32/25     1        1  2025
# 2          ALTAMIRANO, Joaquin Román  42  242  33/25     1        1  2025
# 3                ARANDA, Maia Mariel  42  243  34/25     1        1  2025
# 4     CARRERAS FLAMMINI, Paula Sofía  42  244  35/25     1        1  2025
#
#     fuente                                     archivo_origen
# 0  legajos  C:\ees2-school-database-pipeline\data\raw\lega...
# 1  legajos  C:\ees2-school-database-pipeline\data\raw\lega...
# 2  legajos  C:\ees2-school-database-pipeline\data\raw\lega...
# 3  legajos  C:\ees2-school-database-pipeline\data\raw\lega...
# 4  legajos  C:\ees2-school-database-pipeline\data\raw\lega...

# %%
df_legajos_raw.tail()
# Out:
#    Nº    APELLIDO Y NOMBRES DEL ALUMNO  LM   F    Leg curso division  anio  \
# 22     SANCHEZ PEÑA, Milagros Agostina  43  13  54/25     1        1  2025
# 23                UBEDA, Franco Lionel  43  14  55/25     1        1  2025
# 24               UÑATE, Thiago Santino  43  15  56/25     1        1  2025
# 25           ZACARIAS, Kevin Alejandro  43  16  57/25     1        1  2025
# 26              ZERPA, Fernando Damián  43  17  58/25     1        1  2025
#
#      fuente                                     archivo_origen
# 22  legajos  C:\ees2-school-database-pipeline\data\raw\lega...
# 23  legajos  C:\ees2-school-database-pipeline\data\raw\lega...
# 24  legajos  C:\ees2-school-database-pipeline\data\raw\lega...
# 25  legajos  C:\ees2-school-database-pipeline\data\raw\lega...
# 26  legajos  C:\ees2-school-database-pipeline\data\raw\lega...

# %% [markdown]
# # Prueba de extractores.py para fuente Marzo

# %%
from src.extractores import extraer_marzo_raw

# %%
ruta_marzo = r"C:\ees2-school-database-pipeline\data\raw\marzo\1°1° 2025 Marzo.docx"

df_marzo_raw = extraer_marzo_raw(
    ruta_archivo=ruta_marzo,
    curso="1",
    division="1",
    anio="2025"
)

# %%
df_marzo_raw.shape
# Out:
# (28, 7)

# %%
df_marzo_raw.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Nº                             28 non-null     str
#  1   APELLIDO Y NOMBRES DEL ALUMNO  28 non-null     str
#  2   curso                          28 non-null     str
#  3   division                       28 non-null     str
#  4   anio                           28 non-null     str
#  5   fuente                         28 non-null     str
#  6   archivo_origen                 28 non-null     str
# dtypes: str(7)
# memory usage: 1.7 KB

# %%
df_marzo_raw.head()
# Out:
#   Nº   APELLIDO Y NOMBRES DEL ALUMNO curso division  anio fuente  \
# 0                   ACHIGAR, Tiziano     1        1  2025  marzo
# 1               AGUILAR, Ian Nicolás     1        1  2025  marzo
# 2          ALTAMIRANO, Joaquin Román     1        1  2025  marzo
# 3                ARANDA, Maia Mariel     1        1  2025  marzo
# 4     CARRERAS FLAMMINI, Paula Sofía     1        1  2025  marzo
#
#                                       archivo_origen
# 0  C:\ees2-school-database-pipeline\data\raw\marz...
# 1  C:\ees2-school-database-pipeline\data\raw\marz...
# 2  C:\ees2-school-database-pipeline\data\raw\marz...
# 3  C:\ees2-school-database-pipeline\data\raw\marz...
# 4  C:\ees2-school-database-pipeline\data\raw\marz...

# %% [markdown]
# # Prueba de normalizacion.py para fuente Datos

# %%
from src.normalizacion import normalizar_datos

# %%
df_datos_stg = normalizar_datos(df_datos_raw)

# %%
df_datos_stg.shape
# Out:
# (27, 29)

# %%
df_datos_stg.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   numero_raw               27 non-null     str
#  1   nombre_original          27 non-null     str
#  2   libro_matriz_raw         27 non-null     str
#  3   folio_raw                27 non-null     str
#  4   legajo_raw               27 non-null     str
#  5   escuela_procedencia_raw  27 non-null     str
#  6   dni_raw                  27 non-null     str
#  7   fecha_nacimiento_raw     27 non-null     str
#  8   lugar_nacimiento_raw     27 non-null     str
#  9   edad_raw                 27 non-null     str
#  10  direccion_raw            27 non-null     str
#  11  telefono_raw             27 non-null     str
#  12  curso                    27 non-null     str
#  13  division                 27 non-null     str
#  14  anio                     27 non-null     str
# ...

# %%
df_datos_stg.head()
# Out:
#   numero_raw                 nombre_original libro_matriz_raw folio_raw  \
# 0                           ACHIGAR, Tiziano               42       240
# 1                       AGUILAR, Ian Nicolás               42       241
# 2                  ALTAMIRANO, Joaquin Román               42       242
# 3                        ARANDA, Maia Mariel               42       243
# 4             CARRERAS FLAMMINI, Paula Sofía               42       244
#
#   legajo_raw escuela_procedencia_raw   dni_raw fecha_nacimiento_raw  \
# 0      31/25                      25  52746170             26/12/12
# 1      32/25                       4  52778569             27/11/12
# 2      33/25                       8  52887715             14/01/13
# 3      34/25                       1  52617713             06/07/12
# 4      35/25                       8  52961006             01/02/13
#
#   lugar_nacimiento_raw edad_raw  ... folio legajo escuela_procedencia  \
# ...

# %%
df_datos_stg.columns.tolist()
# Out:
# ['numero_raw',
#  'nombre_original',
#  'libro_matriz_raw',
#  'folio_raw',
#  'legajo_raw',
#  'escuela_procedencia_raw',
#  'dni_raw',
#  'fecha_nacimiento_raw',
#  'lugar_nacimiento_raw',
#  'edad_raw',
#  'direccion_raw',
#  'telefono_raw',
#  'curso',
#  'division',
#  'anio',
#  'fuente',
#  'archivo_origen',
#  'nombre_completo',
#  'libro_matriz',
#  'folio',
#  'legajo',
#  'escuela_procedencia',
#  'dni',
#  'fecha_nacimiento',
#  'lugar_nacimiento',
#  'edad',
#  'direccion',
#  'telefono_num',
#  'tipo_contacto']

# %% [markdown]
# # Prueba de normalizacion.py para fuente Legajos

# %%
from src.normalizacion import normalizar_legajos

# %%
df_legajos_stg = normalizar_legajos(df_legajos_raw)

# %%
df_legajos_stg.shape
# Out:
# (27, 14)

# %%
df_legajos_stg.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   numero_raw        27 non-null     str
#  1   nombre_original   27 non-null     str
#  2   libro_matriz_raw  27 non-null     str
#  3   folio_raw         27 non-null     str
#  4   legajo_raw        27 non-null     str
#  5   curso             27 non-null     str
#  6   division          27 non-null     str
#  7   anio              27 non-null     str
#  8   fuente            27 non-null     str
#  9   archivo_origen    27 non-null     str
#  10  nombre_completo   27 non-null     str
#  11  libro_matriz      27 non-null     str
#  12  folio             27 non-null     str
#  13  legajo            27 non-null     str
# dtypes: str(14)
# memory usage: 3.1 KB

# %%
df_legajos_stg.head()
# Out:
#   numero_raw                 nombre_original libro_matriz_raw folio_raw  \
# 0                           ACHIGAR, Tiziano               42       240
# 1                       AGUILAR, Ian Nicolás               42       241
# 2                  ALTAMIRANO, Joaquin Román               42       242
# 3                        ARANDA, Maia Mariel               42       243
# 4             CARRERAS FLAMMINI, Paula Sofía               42       244
#
#   legajo_raw curso division  anio   fuente  \
# 0      31/25     1        1  2025  legajos
# 1      32/25     1        1  2025  legajos
# 2      33/25     1        1  2025  legajos
# 3      34/25     1        1  2025  legajos
# 4      35/25     1        1  2025  legajos
#
#                                       archivo_origen  \
# 0  C:\ees2-school-database-pipeline\data\raw\lega...
# 1  C:\ees2-school-database-pipeline\data\raw\lega...
# 2  C:\ees2-school-database-pipeline\data\raw\lega...
# ...

# %%
df_legajos_stg.columns.tolist()
# Out:
# ['numero_raw',
#  'nombre_original',
#  'libro_matriz_raw',
#  'folio_raw',
#  'legajo_raw',
#  'curso',
#  'division',
#  'anio',
#  'fuente',
#  'archivo_origen',
#  'nombre_completo',
#  'libro_matriz',
#  'folio',
#  'legajo']

# %% [markdown]
# # Prueba de normalizacion.py para fuente Marzo

# %%
from src.normalizacion import normalizar_marzo

# %%
df_marzo_stg = normalizar_marzo(df_marzo_raw)

# %%
df_marzo_stg.shape
# Out:
# (28, 11)

# %%
df_marzo_stg.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   numero_raw            28 non-null     str
#  1   nombre_original       28 non-null     str
#  2   curso                 28 non-null     str
#  3   division              28 non-null     str
#  4   anio                  28 non-null     str
#  5   fuente                28 non-null     str
#  6   archivo_origen        28 non-null     str
#  7   nombre_completo       28 non-null     str
#  8   observacion_marzo     0 non-null      object
#  9   tipo_evento_inferido  28 non-null     str
#  10  requiere_revision     28 non-null     bool
# dtypes: bool(1), object(1), str(9)
# memory usage: 2.3+ KB

# %%
df_marzo_stg.head()
# Out:
#   numero_raw                 nombre_original curso division  anio fuente  \
# 0                           ACHIGAR, Tiziano     1        1  2025  marzo
# 1                       AGUILAR, Ian Nicolás     1        1  2025  marzo
# 2                  ALTAMIRANO, Joaquin Román     1        1  2025  marzo
# 3                        ARANDA, Maia Mariel     1        1  2025  marzo
# 4             CARRERAS FLAMMINI, Paula Sofía     1        1  2025  marzo
#
#                                       archivo_origen  \
# 0  C:\ees2-school-database-pipeline\data\raw\marz...
# 1  C:\ees2-school-database-pipeline\data\raw\marz...
# 2  C:\ees2-school-database-pipeline\data\raw\marz...
# 3  C:\ees2-school-database-pipeline\data\raw\marz...
# 4  C:\ees2-school-database-pipeline\data\raw\marz...
#
#                   nombre_completo observacion_marzo tipo_evento_inferido  \
# 0                ACHIGAR, Tiziano              None     presencia_simple
# ...

# %%
df_marzo_stg.columns.tolist()
# Out:
# ['numero_raw',
#  'nombre_original',
#  'curso',
#  'division',
#  'anio',
#  'fuente',
#  'archivo_origen',
#  'nombre_completo',
#  'observacion_marzo',
#  'tipo_evento_inferido',
#  'requiere_revision']
